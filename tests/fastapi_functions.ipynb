# %%
import pandas as pd
import locale

# %%
movies_df = pd.read_parquet('../data/movies_dataset/movies_ETL.parquet', engine='fastparquet')

# %%
movies_df.head()
# Out:
#      budget     id original_language  \
# 0  30000000    862                en
# 1  65000000   8844                en
# 2         0  15602                en
# 3  16000000  31357                en
# 4         0  11862                en
#
#                                             overview  popularity release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...   21.946943   1995-10-30
# 1  When siblings Judy and Peter discover an encha...   17.015539   1995-12-15
# 2  A family wedding reignites the ancient feud be...   11.712900   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...    3.859495   1995-12-22
# 4  Just when George Banks has recovered from his ...    8.387519   1995-02-10
#
#      revenue  runtime    status  \
# 0  373554033     81.0  Released
# 1  262797249    104.0  Released
# 2          0    101.0  Released
# 3   81452156    127.0  Released
# 4   76578911    106.0  Released
#
#                                              tagline  \
# 0                                               None
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  vote_average  vote_count  release_year  \
# 0                    Toy Story           7.7        5415          1995
# 1                      Jumanji           6.9        2413          1995
# 2             Grumpier Old Men           6.5          92          1995
# 3            Waiting to Exhale           6.1          34          1995
# 4  Father of the Bride Part II           5.7         173          1995
#
#       return
# 0  12.451801
# 1   4.043035
# 2   0.000000
# 3   5.090760
# 4   0.000000

# %%
movies_df['release_date']
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 45371   1991-05-13
# 45372   2011-11-17
# 45373   2003-08-01
# 45374   1917-10-21
# 45375   2017-06-09
# Name: release_date, Length: 45376, dtype: datetime64[ns]

# %%
meses_serie = movies_df['release_date'].dt.month

# %%
meses_serie
# Out:
# 0        10
# 1        12
# 2        12
# 3        12
# 4         2
#          ..
# 45371     5
# 45372    11
# 45373     8
# 45374    10
# 45375     6
# Name: release_date, Length: 45376, dtype: int32

# %%
meses_list = meses_serie.tolist()

# %%
meses_list
# Out:
# [10,
#  12,
#  12,
#  12,
#  2,
#  12,
#  12,
#  12,
#  12,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  11,
#  12,
#  12,
#  11,
#  11,
#  10,
#  10,
#  10,
#  10,
#  10,
#  12,
#  10,
#  9,
#  5,
#  4,
#  8,
#  12,
#  9,
#  7,
#  11,
#  12,
#  10,
#  11,
#  7,
#  12,
#  12,
#  10,
#  12,
#  8,
#  5,
#  10,
#  9,
#  6,
#  5,
#  7,
#  11,
#  9,
#  1,
#  9,
#  5,
#  7,
#  11,
#  9,
#  9,
#  7,
#  1,
#  12,
#  1,
#  1,
#  1,
#  1,
#  10,
#  2,
#  4,
#  1,
#  11,
#  10,
#  3,
#  1,
#  1,
#  9,
#  2,
#  11,
#  2,
#  1,
#  12,
#  9,
#  1,
#  11,
#  9,
#  2,
#  1,
#  2,
#  11,
#  9,
#  2,
#  10,
#  2,
#  2,
#  12,
#  5,
#  12,
#  12,
#  2,
#  2,
#  2,
#  2,
#  2,
#  5,
#  11,
#  2,
#  12,
#  5,
#  5,
#  2,
#  1,
#  2,
#  9,
#  1,
#  6,
#  1,
#  3,
#  9,
#  3,
#  12,
#  6,
#  7,
#  9,
#  3,
#  10,
#  9,
#  1,
#  2,
#  1,
#  11,
#  10,
#  8,
#  8,
#  3,
#  9,
#  9,
#  8,
#  8,
#  3,
#  3,
#  10,
#  8,
#  4,
#  8,
#  4,
#  7,
#  8,
#  6,
#  4,
#  1,
#  6,
#  5,
#  5,
#  9,
#  6,
#  5,
#  9,
#  6,
#  5,
#  9,
#  8,
#  9,
#  5,
#  10,
#  10,
#  7,
#  7,
#  9,
#  8,
#  5,
#  6,
#  4,
#  7,
#  1,
#  8,
#  5,
#  5,
#  10,
#  6,
#  9,
#  9,
#  9,
#  7,
#  7,
#  6,
#  9,
#  11,
#  6,
#  10,
#  8,
#  9,
#  6,
#  8,
#  7,
#  9,
#  10,
#  2,
#  9,
#  10,
#  11,
#  9,
#  7,
#  9,
#  8,
#  8,
#  7,
#  12,
#  12,
#  10,
#  8,
#  5,
#  6,
#  1,
#  2,
#  10,
#  2,
#  4,
#  8,
#  3,
#  9,
#  10,
#  12,
#  1,
#  12,
#  4,
#  5,
#  3,
#  12,
#  8,
#  9,
#  10,
#  9,
#  5,
#  5,
#  1,
#  4,
#  3,
#  6,
#  12,
#  5,
#  12,
#  9,
#  9,
#  9,
#  1,
#  12,
#  2,
#  2,
#  12,
#  11,
#  3,
#  2,
#  11,
#  2,
#  8,
#  4,
#  5,
#  12,
#  5,
#  2,
#  2,
#  4,
#  12,
#  3,
#  10,
#  6,
#  10,
#  3,
#  12,
#  11,
#  3,
#  12,
#  8,
#  11,
#  1,
#  5,
#  1,
#  12,
#  12,
#  4,
#  8,
#  4,
#  9,
#  3,
#  8,
#  9,
#  9,
#  1,
#  3,
#  9,
#  5,
#  4,
#  9,
#  11,
#  2,
#  1,
#  9,
#  5,
#  5,
#  2,
#  3,
#  12,
#  5,
#  1,
#  1,
#  10,
#  1,
#  10,
#  4,
#  11,
#  1,
#  10,
#  10,
#  11,
#  9,
#  12,
#  9,
#  1,
#  9,
#  7,
#  9,
#  6,
#  3,
#  1,
#  11,
#  5,
#  4,
#  4,
#  3,
#  9,
#  4,
#  2,
#  12,
#  8,
#  4,
#  11,
#  9,
#  9,
#  8,
#  2,
#  5,
#  4,
#  9,
#  10,
#  8,
#  7,
#  8,
#  5,
#  5,
#  12,
#  5,
#  7,
#  3,
#  1,
#  10,
#  6,
#  7,
#  12,
#  9,
#  6,
#  12,
#  10,
#  7,
#  5,
#  9,
#  3,
#  3,
#  2,
#  7,
#  12,
#  12,
#  9,
#  6,
#  12,
#  9,
#  7,
#  4,
#  6,
#  6,
#  1,
#  12,
#  9,
#  11,
#  9,
#  1,
#  8,
#  9,
#  12,
#  12,
#  9,
#  12,
#  5,
#  1,
#  10,
#  10,
#  5,
#  11,
#  5,
#  5,
#  3,
#  11,
#  2,
#  12,
#  2,
#  3,
#  11,
#  4,
#  9,
#  8,
#  1,
#  7,
#  4,
#  7,
#  5,
#  10,
#  5,
#  7,
#  1,
#  7,
#  2,
#  9,
#  6,
#  6,
#  9,
#  1,
#  9,
#  11,
#  6,
#  5,
#  5,
#  7,
#  8,
#  4,
#  6,
#  11,
#  5,
#  9,
#  10,
#  6,
#  5,
#  10,
#  9,
#  4,
#  10,
#  10,
#  4,
#  11,
#  5,
#  10,
#  6,
#  7,
#  8,
#  8,
#  12,
#  2,
#  6,
#  6,
#  7,
#  6,
#  8,
#  12,
#  5,
#  12,
#  5,
#  10,
#  1,
#  3,
#  2,
#  8,
#  7,
#  12,
#  4,
#  6,
#  3,
#  10,
#  6,
#  9,
#  10,
#  8,
#  7,
#  6,
#  6,
#  3,
#  9,
#  5,
#  9,
#  8,
#  8,
#  5,
#  3,
#  5,
#  9,
#  5,
#  10,
#  10,
#  11,
#  9,
#  7,
#  9,
#  4,
#  7,
#  9,
#  11,
#  12,
#  5,
#  7,
#  9,
#  10,
#  10,
#  3,
#  11,
#  6,
#  7,
#  10,
#  4,
#  7,
#  9,
#  3,
#  10,
#  9,
#  11,
#  8,
#  11,
#  9,
#  8,
#  9,
#  8,
#  4,
#  7,
#  12,
#  9,
#  9,
#  10,
#  12,
#  6,
#  5,
#  6,
#  7,
#  7,
#  9,
#  11,
#  5,
#  4,
#  9,
#  11,
#  4,
#  10,
#  11,
#  12,
#  9,
#  9,
#  12,
#  11,
#  2,
#  1,
#  9,
#  5,
#  9,
#  4,
#  9,
#  11,
#  10,
#  1,
#  6,
#  9,
#  9,
#  7,
#  10,
#  1,
#  8,
#  9,
#  8,
#  1,
#  9,
#  1,
#  1,
#  10,
#  5,
#  2,
#  11,
#  7,
#  11,
#  7,
#  11,
#  2,
#  6,
#  2,
#  12,
#  11,
#  2,
#  3,
#  12,
#  6,
#  11,
#  2,
#  9,
#  3,
#  12,
#  3,
#  12,
#  4,
#  3,
#  8,
#  3,
#  5,
#  2,
#  4,
#  5,
#  12,
#  9,
#  2,
#  3,
#  1,
#  5,
#  9,
#  12,
#  1,
#  4,
#  9,
#  4,
#  9,
#  1,
#  3,
#  1,
#  5,
#  12,
#  3,
#  3,
#  3,
#  6,
#  3,
#  3,
#  12,
#  9,
#  3,
#  3,
#  4,
#  7,
#  5,
#  2,
#  6,
#  3,
#  4,
#  5,
#  2,
#  9,
#  5,
#  12,
#  7,
#  3,
#  8,
#  4,
#  4,
#  4,
#  4,
#  4,
#  3,
#  3,
#  8,
#  5,
#  4,
#  3,
#  11,
#  10,
#  1,
#  1,
#  3,
#  9,
#  5,
#  11,
#  1,
#  5,
#  1,
#  3,
#  10,
#  7,
#  2,
#  4,
#  10,
#  1,
#  4,
#  3,
#  8,
#  9,
#  6,
#  1,
#  9,
#  9,
#  11,
#  5,
#  4,
#  3,
#  4,
#  4,
#  4,
#  11,
#  4,
#  5,
#  5,
#  5,
#  12,
#  9,
#  1,
#  11,
#  1,
#  7,
#  5,
#  3,
#  5,
#  5,
#  5,
#  1,
#  8,
#  5,
#  5,
#  6,
#  4,
#  3,
#  5,
#  5,
#  10,
#  4,
#  11,
#  10,
#  5,
#  8,
#  12,
#  12,
#  8,
#  5,
#  8,
#  1,
#  9,
#  9,
#  11,
#  12,
#  4,
#  9,
#  4,
#  11,
#  1,
#  6,
#  6,
#  12,
#  1,
#  8,
#  5,
#  9,
#  9,
#  11,
#  5,
#  7,
#  1,
#  5,
#  5,
#  1,
#  2,
#  5,
#  6,
#  3,
#  8,
#  6,
#  6,
#  7,
#  6,
#  1,
#  6,
#  8,
#  5,
#  1,
#  1,
#  9,
#  9,
#  1,
#  9,
#  12,
#  7,
#  6,
#  7,
#  7,
#  7,
#  8,
#  7,
#  9,
#  3,
#  8,
#  7,
#  7,
#  10,
#  10,
#  5,
#  5,
#  9,
#  8,
#  5,
#  9,
#  1,
#  3,
#  9,
#  5,
#  6,
#  9,
#  7,
#  7,
#  9,
#  10,
#  11,
#  10,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  8,
#  1,
#  8,
#  6,
#  3,
#  1,
#  9,
#  9,
#  8,
#  8,
#  1,
#  8,
#  8,
#  6,
#  6,
#  8,
#  1,
#  1,
#  3,
#  10,
#  7,
#  1,
#  4,
#  4,
#  9,
#  8,
#  11,
#  8,
#  5,
#  7,
#  9,
#  1,
#  9,
#  1,
#  10,
#  8,
#  8,
#  1,
#  8,
#  8,
#  8,
#  6,
#  9,
#  9,
#  10,
#  3,
#  9,
#  10,
#  9,
#  10,
#  11,
#  3,
#  5,
#  5,
#  7,
#  12,
#  4,
#  8,
#  2,
#  10,
#  5,
#  8,
#  2,
#  5,
#  10,
#  7,
#  6,
#  3,
#  12,
#  11,
#  11,
#  10,
#  9,
#  9,
#  3,
#  11,
#  8,
#  12,
#  10,
#  8,
#  4,
#  4,
#  8,
#  11,
#  1,
#  4,
#  8,
#  8,
#  12,
#  7,
#  8,
#  6,
#  8,
#  10,
#  6,
#  4,
#  1,
#  5,
#  11,
#  10,
#  6,
#  9,
#  9,
#  3,
#  9,
#  10,
#  3,
#  5,
#  1,
#  10,
#  12,
#  10,
#  2,
#  4,
#  8,
#  6,
#  7,
#  9,
#  3,
#  1,
#  12,
#  2,
#  6,
#  12,
#  2,
#  10,
#  12,
#  11,
#  2,
#  1,
#  3,
#  6,
#  9,
#  12,
#  3,
#  10,
#  1,
#  2,
#  11,
#  1,
#  7,
#  1,
#  9,
#  4,
#  9,
#  9,
#  9,
#  10,
#  9,
#  10,
#  9,
#  9,
#  1,
#  11,
#  9,
#  9,
#  8,
#  10,
#  9,
#  10,
#  10,
#  10,
#  7,
#  5,
#  3,
#  12,
#  2,
#  12,
#  6,
#  5,
#  2,
#  3,
#  12,
#  12,
#  12,
#  9,
#  7,
#  3,
#  12,
#  7,
#  12,
#  11,
#  6,
#  8,
#  10,
#  11,
#  ...]

# %%
print(meses_list)
# Out:
# [10, 12, 12, 12, 2, 12, 12, 12, 12, 11, 11, 12, 12, 12, 12, 11, 12, 12, 11, 11, 10, 10, 10, 10, 10, 12, 10, 9, 5, 4, 8, 12, 9, 7, 11, 12, 10, 11, 7, 12, 12, 10, 12, 8, 5, 10, 9, 6, 5, 7, 11, 9, 1, 9, 5, 7, 11, 9, 9, 7, 1, 12, 1, 1, 1, 1, 10, 2, 4, 1, 11, 10, 3, 1, 1, 9, 2, 11, 2, 1, 12, 9, 1, 11, 9, 2, 1, 2, 11, 9, 2, 10, 2, 2, 12, 5, 12, 12, 2, 2, 2, 2, 2, 5, 11, 2, 12, 5, 5, 2, 1, 2, 9, 1, 6, 1, 3, 9, 3, 12, 6, 7, 9, 3, 10, 9, 1, 2, 1, 11, 10, 8, 8, 3, 9, 9, 8, 8, 3, 3, 10, 8, 4, 8, 4, 7, 8, 6, 4, 1, 6, 5, 5, 9, 6, 5, 9, 6, 5, 9, 8, 9, 5, 10, 10, 7, 7, 9, 8, 5, 6, 4, 7, 1, 8, 5, 5, 10, 6, 9, 9, 9, 7, 7, 6, 9, 11, 6, 10, 8, 9, 6, 8, 7, 9, 10, 2, 9, 10, 11, 9, 7, 9, 8, 8, 7, 12, 12, 10, 8, 5, 6, 1, 2, 10, 2, 4, 8, 3, 9, 10, 12, 1, 12, 4, 5, 3, 12, 8, 9, 10, 9, 5, 5, 1, 4, 3, 6, 12, 5, 12, 9, 9, 9, 1, 12, 2, 2, 12, 11, 3, 2, 11, 2, 8, 4, 5, 12, 5, 2, 2, 4, 12, 3, 10, 6, 10, 3, 12, 11, 3, 12, 8, 11, 1, 5, 1, 12, 12, 4, 8, 4, 9, 3, 8, 9, 9, 1, 3, 9, 5, 4, 9, 11, 2, 1, 9, 5, 5, 2, 3, 12, 5, 1, 1, 10, 1, 10, 4, 11, 1, 10, 10, 11, 9, 12, 9, 1, 9, 7, 9, 6, 3, 1, 11, 5, 4, 4, 3, 9, 4, 2, 12, 8, 4, 11, 9, 9, 8, 2, 5, 4, 9, 10, 8, 7, 8, 5, 5, 12, 5, 7, 3, 1, 10, 6, 7, 12, 9, 6, 12, 10, 7, 5, 9, 3, 3, 2, 7, 12, 12, 9, 6, 12, 9, 7, 4, 6, 6, 1, 12, 9, 11, 9, 1, 8, 9, 12, 12, 9, 12, 5, 1, 10, 10, 5, 11, 5, 5, 3, 11, 2, 12, 2, 3, 11, 4, 9, 8, 1, 7, 4, 7, 5, 10, 5, 7, 1, 7, 2, 9, 6, 6, 9, 1, 9, 11, 6, 5, 5, 7, 8, 4, 6, 11, 5, 9, 10, 6, 5, 10, 9, 4, 10, 10, 4, 11, 5, 10, 6, 7, 8, 8, 12, 2, 6, 6, 7, 6, 8, 12, 5, 12, 5, 10, 1, 3, 2, 8, 7, 12, 4, 6, 3, 10, 6, 9, 10, 8, 7, 6, 6, 3, 9, 5, 9, 8, 8, 5, 3, 5, 9, 5, 10, 10, 11, 9, 7, 9, 4, 7, 9, 11, 12, 5, 7, 9, 10, 10, 3, 11, 6, 7, 10, 4, 7, 9, 3, 10, 9, 11, 8, 11, 9, 8, 9, 8, 4, 7, 12, 9, 9, 10, 12, 6, 5, 6, 7, 7, 9, 11, 5, 4, 9, 11, 4, 10, 11, 12, 9, 9, 12, 11, 2, 1, 9, 5, 9, 4, 9, 11, 10, 1, 6, 9, 9, 7, 10, 1, 8, 9, 8, 1, 9, 1, 1, 10, 5, 2, 11, 7, 11, 7, 11, 2, 6, 2, 12, 11, 2, 3, 12, 6, 11, 2, 9, 3, 12, 3, 12, 4, 3, 8, 3, 5, 2, 4, 5, 12, 9, 2, 3, 1, 5, 9, 12, 1, 4, 9, 4, 9, 1, 3, 1, 5, 12, 3, 3, 3, 6, 3, 3, 12, 9, 3, 3, 4, 7, 5, 2, 6, 3, 4, 5, 2, 9, 5, 12, 7, 3, 8, 4, 4, 4, 4, 4, 3, 3, 8, 5, 4, 3, 11, 10, 1, 1, 3, 9, 5, 11, 1, 5, 1, 3, 10, 7, 2, 4, 10, 1, 4, 3, 8, 9, 6, 1, 9, 9, 11, 5, 4, 3, 4, 4, 4, 11, 4, 5, 5, 5, 12, 9, 1, 11, 1, 7, 5, 3, 5, 5, 5, 1, 8, 5, 5, 6, 4, 3, 5, 5, 10, 4, 11, 10, 5, 8, 12, 12, 8, 5, 8, 1, 9, 9, 11, 12, 4, 9, 4, 11, 1, 6, 6, 12, 1, 8, 5, 9, 9, 11, 5, 7, 1, 5, 5, 1, 2, 5, 6, 3, 8, 6, 6, 7, 6, 1, 6, 8, 5, 1, 1, 9, 9, 1, 9, 12, 7, 6, 7, 7, 7, 8, 7, 9, 3, 8, 7, 7, 10, 10, 5, 5, 9, 8, 5, 9, 1, 3, 9, 5, 6, 9, 7, 7, 9, 10, 11, 10, 8, 8, 8, 8, 8, 8, 8, 1, 8, 6, 3, 1, 9, 9, 8, 8, 1, 8, 8, 6, 6, 8, 1, 1, 3, 10, 7, 1, 4, 4, 9, 8, 11, 8, 5, 7, 9, 1, 9, 1, 10, 8, 8, 1, 8, 8, 8, 6, 9, 9, 10, 3, 9, 10, 9, 10, 11, 3, 5, 5, 7, 12, 4, 8, 2, 10, 5, 8, 2, 5, 10, 7, 6, 3, 12, 11, 11, 10, 9, 9, 3, 11, 8, 12, 10, 8, 4, 4, 8, 11, 1, 4, 8, 8, 12, 7, 8, 6, 8, 10, 6, 4, 1, 5, 11, 10, 6, 9, 9, 3, 9, 10, 3, 5, 1, 10, 12, 10, 2, 4, 8, 6, 7, 9, 3, 1, 12, 2, 6, 12, 2, 10, 12, 11, 2, 1, 3, 6, 9, 12, 3, 10, 1, 2, 11, 1, 7, 1, 9, 4, 9, 9, 9, 10, 9, 10, 9, 9, 1, 11, 9, 9, 8, 10, 9, 10, 10, 10, 7, 5, 3, 12, 2, 12, 6, 5, 2, 3, 12, 12, 12, 9, 7, 3, 12, 7, 12, 11, 6, 8, 10, 11, 10, 7, 7, 8, 3, 7, 3, 9, 9, 11, 5, 10, 10, 9, 5, 6, 10, 10, 10, 10, 9, 1, 10, 1, 2, 12, 2, 10, 10, 10, 5, 12, 5, 2, 5, 11, 7, 12, 4, 10, 6, 1, 12, 12, 4, 7, 8, 4, 8, 7, 7, 10, 5, 11, 8, 9, 12, 7, 3, 3, 9, 9, 12, 4, 11, 12, 6, 5, 9, 10, 9, 10, 9, 10, 9, 5, 9, 10, 1, 10, 5, 1, 1, 3, 10, 10, 6, 12, 5, 4, 8, 2, 5, 4, 8, 11, 1, 10, 3, 7, 9, 9, 9, 5, 9, 10, 9, 10, 12, 3, 5, 9, 11, 5, 12, 10, 9, 9, 4, 2, 5, 9, 3, 3, 10, 11, 11, 9, 5, 9, 11, 9, 5, 4, 5, 11, 9, 9, 12, 10, 11, 1, 7, 8, 12, 8, 8, 12, 5, 3, 11, 1, 5, 9, 6, 2, 7, 12, 1, 3, 12, 12, 12, 8, 12, 5, 1, 8, 9, 5, 10, 5, 6, 7, 6, 6, 12, 6, 5, 10, 10, 7, 2, 11, 4, 10, 4, 9, 12, 12, 9, 2, 2, 10, 8, 12, 2, 4, 9, 6, 12, 4, 2, 10, 2, 6, 9, 1, 12, 11, 10, 5, 8, 5, 3, 6, 12, 3, 2, 8, 10, 8, 9, 7, ...

# %%
def cantidad_filmaciones_mes(mes):
    months = {
        'Enero': '1', 
        'Febrero': '2', 
        'Marzo': '3', 
        'Abril': '4', 
        'Mayo': '5', 
        'Junio': '6', 
        'Julio': '7', 
        'Agosto': '8', 
        'Septiembre': '9', 
        'Octubre': '10', 
        'Noviembre': '11', 
        'Diciembre': '12'
    }
    mes_num = int(months.get(mes))
    meses_series = movies_df['release_date'].dt.month
    meses_list = meses_series.tolist()
    cantidad = 0
    for m in meses_list:
        if m == mes_num:
            cantidad+=1
    return (cantidad, mes)

# %%
cantidad, mes = cantidad_filmaciones_mes('Diciembre')

# %%
print(cantidad)
print(mes)
# Out:
# 3786
# Diciembre

# %%
months = {
    'Enero': '1', 
    'Febrero': '2', 
    'Marzo': '3', 
    'Abril': '4', 
    'Mayo': '5', 
    'Junio': '6', 
    'Julio': '7', 
    'Agosto': '8', 
    'Septiembre': '9', 
    'Octubre': '10', 
    'Noviembre': '11', 
    'Diciembre': '12'
}
mes_num = months.get('Diciembre')
mes_num
# Out:
# '12'

# %%
for m in meses_list:
    if m == 1:
        cantidad+=1

# %%
locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')
# Out:
# 'es_ES.UTF-8'

# %%
dates = pd.DataFrame(movies_df['release_date'])

# %%
dates
# Out:
#       release_date
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
# ...            ...
# 45371   1991-05-13
# 45372   2011-11-17
# 45373   2003-08-01
# 45374   1917-10-21
# 45375   2017-06-09
#
# [45376 rows x 1 columns]

# %%
dates['Nombre_de_dia'] = dates['release_date'].dt.strftime('%A')

# %%
dates
# Out:
#       release_date Nombre_de_dia
# 0       1995-10-30         lunes
# 1       1995-12-15       viernes
# 2       1995-12-22       viernes
# 3       1995-12-22       viernes
# 4       1995-02-10       viernes
# ...            ...           ...
# 45371   1991-05-13         lunes
# 45372   2011-11-17        jueves
# 45373   2003-08-01       viernes
# 45374   1917-10-21       domingo
# 45375   2017-06-09       viernes
#
# [45376 rows x 2 columns]

# %%
cantidad_filmaciones_dia('lunes')
# Out:
# (3503, 'lunes')

# %%
def cantidad_filmaciones_dia(dia):
    locale.setlocale(locale.LC_TIME, 'es_ES.UTF-8')
    date = pd.DataFrame(movies_df['release_date'])
    date['nombre_de_dia'] = (date['release_date'].dt.strftime('%A'))
    nombre_de_dia_list = date['nombre_de_dia'].tolist()
    cantidad = nombre_de_dia_list.count(dia)
    return (cantidad, dia)

# %%
date = pd.DataFrame(movies_df['release_date'])
date['nombre_de_dia'] = (date['release_date'].dt.strftime('%A'))
nombre_de_dia_list = date['nombre_de_dia'].tolist()

# %%
nombre_de_dia_list.count('jueves')
# Out:
# 7525

# %%
cantidad_filmaciones_mes('enero')
# Out:
# 5912

# %%
def cantidad_filmaciones_mes(mes):
    months = {
        'enero': '1', 
        'febrero': '2', 
        'marzo': '3', 
        'abril': '4', 
        'mayo': '5', 
        'junio': '6', 
        'julio': '7', 
        'agosto': '8', 
        'septiembre': '9', 
        'octubre': '10', 
        'noviembre': '11', 
        'diciembre': '12'
    }
    mes_num = int(months.get(mes))
    meses_series = movies_df['release_date'].dt.month
    meses_list = meses_series.tolist()
    cantidad = meses_list.count(mes_num)
    return (cantidad)

# %%
cantidad_filmaciones_dia("martes")
# Out:
# 4641

# %%
def cantidad_filmaciones_dia(dia):
    dias = {
        'lunes': 'Monday', 
        'martes': 'Tuesday', 
        'miercoles': 'Wednesday', 
        'jueves': 'Thursday', 
        'viernes': 'Friday', 
        'sabado': 'Saturday', 
        'domingo': 'Sunday'
    }
    day = dias.get(dia)
    date = pd.DataFrame(movies_df['release_date'])
    date['nombre_de_dia'] = (date['release_date'].dt.strftime('%A'))
    nombre_de_dia_list = date['nombre_de_dia'].tolist()
    cantidad = nombre_de_dia_list.count(day)
    return (cantidad)

# %%
date = pd.DataFrame(movies_df['release_date'])
date['nombre_de_dia'] = (date['release_date'].dt.strftime('%A'))
nombre_de_dia_list = date['nombre_de_dia'].tolist()

# %%
def score_titulo(titulo_de_la_filmación):
    year_score_df = pd.DataFrame(movies_df[['release_year']])

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45376 entries, 0 to 45375
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             45376 non-null  int64
#  1   id                 45376 non-null  object
#  2   original_language  45365 non-null  object
#  3   overview           44435 non-null  object
#  4   popularity         45376 non-null  float64
#  5   release_date       45376 non-null  datetime64[ns]
#  6   revenue            45376 non-null  int64
#  7   runtime            45130 non-null  float64
#  8   status             45296 non-null  object
#  9   tagline            20398 non-null  object
#  10  title              45376 non-null  object
#  11  vote_average       45376 non-null  float64
#  12  vote_count         45376 non-null  int32
#  13  release_year       45376 non-null  int32
#  14  return             45376 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(2), object(6)
# memory usage: 4.8+ MB

# %%
title_year_score_df = pd.DataFrame(movies_df[['title','release_year','popularity']])
title_year_score_df
# Out:
#                              title  release_year  popularity
# 0                        Toy Story          1995   21.946943
# 1                          Jumanji          1995   17.015539
# 2                 Grumpier Old Men          1995   11.712900
# 3                Waiting to Exhale          1995    3.859495
# 4      Father of the Bride Part II          1995    8.387519
# ...                            ...           ...         ...
# 45371                   Robin Hood          1991    5.683753
# 45372          Century of Birthing          2011    0.178241
# 45373                     Betrayal          2003    0.903007
# 45374             Satan Triumphant          1917    0.003503
# 45375                     Queerama          2017    0.163015
#
# [45376 rows x 3 columns]

# %%
title_year_score_df.set_index('title', inplace=True)
title_year_score_df.head()
# Out:
#                              release_year  popularity
# title
# Toy Story                            1995   21.946943
# Jumanji                              1995   17.015539
# Grumpier Old Men                     1995   11.712900
# Waiting to Exhale                    1995    3.859495
# Father of the Bride Part II          1995    8.387519

# %%
type(title_year_score_df.loc['Waiting to Exhale'])
# Out:
# pandas.core.series.Series

# %%
year_score_series = title_year_score_df.loc['Waiting to Exhale']

# %%
year_score_series
# Out:
# release_year    1995.000000
# popularity         3.859495
# Name: Waiting to Exhale, dtype: float64

# %%
año = year_score_series['release_year']
año
# Out:
# 1995.0

# %%
popularidad = year_score_series['popularity']
popularidad
# Out:
# 3.859495

# %%
score_titulo('Alien')
# Out:
# (1979, 23.37742)

# %%
año, score = score_titulo('Alien')
print(año, score)
# Out:
# 1979 23.37742

# %%
def score_titulo(titulo_de_la_filmación):
    title_year_popularity_df = pd.DataFrame(movies_df[['title','release_year','popularity']])
    title_year_popularity_df.set_index('title', inplace=True)
    year_popularity_series = title_year_popularity_df.loc[titulo_de_la_filmación]
    año = year_popularity_series['release_year']
    año = int(año)
    popularidad = year_popularity_series['popularity']
    return (año, popularidad)

# %%
movies_df.iloc[10]
# Out:
# budget                                                        62000000
# id                                                                9087
# original_language                                                   en
# overview             Widowed U.S. president Andrew Shepherd, one of...
# popularity                                                    6.318445
# release_date                                       1995-11-17 00:00:00
# revenue                                                      107879496
# runtime                                                          106.0
# status                                                        Released
# tagline              Why can't the most powerful man in the world h...
# title                                           The American President
# vote_average                                                       6.5
# vote_count                                                         199
# release_year                                                      1995
# return                                                        1.739992
# Name: 10, dtype: object

# %%
def votos_titulo(titulo_de_la_filmación):
    title_year_count_average_df = pd.DataFrame(movies_df[['title','release_year','vote_count','vote_average']])
    title_year_count_average_df.set_index('title', inplace=True)
    title_year_count_average_series = title_year_count_average_df.loc[titulo_de_la_filmación]
    año = title_year_count_average_series['release_year']
    año = int(año)
    cantidad_de_votos = title_year_count_average_series['vote_count']
    promedio_de_votos = title_year_count_average_series['vote_average']
    return (año, cantidad_de_votos, promedio_de_votos)

# %%
votos_titulo("The American President")
# Out:
# (1995, 199.0, 6.5)

# %%
año, votos, promedio_votos = votos_titulo("The American President")
print(año)
print(votos)
print(promedio_votos)
# Out:
# 1995
# 199.0
# 6.5

# %%
cast_df = pd.read_parquet('../data/credits/cast_ETL.parquet', engine='fastparquet')

# %%
cast_df.iloc[1]
# Out:
# cast_id                                       15
# character                 Buzz Lightyear (voice)
# credit_id               52fe4284c3a36847f8024f99
# gender                                         2
# id                                         12898
# name                                   Tim Allen
# order                                          1
# profile_path    /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# movie_id                                     862
# Name: 1, dtype: object

# %%
name_movieId = cast_df[['name', 'movie_id']]

# %%
name_movieId_tom_hanks = name_movieId[name_movieId['name'] == "Tom Hanks"]

# %%
name_movieId_tom_hanks
# Out:
#              name movie_id
# 0       Tom Hanks      862
# 2393    Tom Hanks      568
# 5859    Tom Hanks       13
# 8489    Tom Hanks     9800
# 9083    Tom Hanks      858
# ...           ...      ...
# 504992  Tom Hanks   363676
# 520042  Tom Hanks   207932
# 538742  Tom Hanks   140465
# 541857  Tom Hanks   305642
# 542087  Tom Hanks   331214
#
# [72 rows x 2 columns]

# %%
conteo_valor = name_movieId_tom_hanks['movie_id'].value_counts().get("208988", 0)

# %%
conteo_valor
# Out:
# 2

# %%
name_movieId_tom_hanks[name_movieId_tom_hanks.duplicated(subset=['movie_id'])]
# Out:
#              name movie_id
# 285591  Tom Hanks   208988

# %%
name_movieId_tom_hanks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 0 to 542087
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      72 non-null     object
#  1   movie_id  72 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
name_movieId_tom_hanks = name_movieId_tom_hanks.drop_duplicates()

# %%
name_movieId_tom_hanks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71 entries, 0 to 542087
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      71 non-null     object
#  1   movie_id  71 non-null     object
# dtypes: object(2)
# memory usage: 1.7+ KB

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45376 entries, 0 to 45375
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   budget             45376 non-null  int64
#  1   id                 45376 non-null  object
#  2   original_language  45365 non-null  object
#  3   overview           44435 non-null  object
#  4   popularity         45376 non-null  float64
#  5   release_date       45376 non-null  datetime64[ns]
#  6   revenue            45376 non-null  int64
#  7   runtime            45130 non-null  float64
#  8   status             45296 non-null  object
#  9   tagline            20398 non-null  object
#  10  title              45376 non-null  object
#  11  vote_average       45376 non-null  float64
#  12  vote_count         45376 non-null  int32
#  13  release_year       45376 non-null  int32
#  14  return             45376 non-null  float64
# dtypes: datetime64[ns](1), float64(4), int32(2), int64(2), object(6)
# memory usage: 4.8+ MB

# %%
movies_df[movies_df['id'] == "208988"]
# Out:
#        budget      id original_language  \
# 19144       0  208988                en
#
#                                                 overview  popularity  \
# 19144  The War is a seven episode documentary miniser...    0.487489
#
#       release_date  revenue  runtime    status tagline    title  vote_average  \
# 19144   2007-09-23        0    874.0  Released    None  The War           5.3
#
#        vote_count  release_year  return
# 19144           3          2007     0.0

# %%
movieId_title_return = pd.DataFrame(movies_df[['id','title','return']])
movieId_title_return
# Out:
#            id                        title     return
# 0         862                    Toy Story  12.451801
# 1        8844                      Jumanji   4.043035
# 2       15602             Grumpier Old Men   0.000000
# 3       31357            Waiting to Exhale   5.090760
# 4       11862  Father of the Bride Part II   0.000000
# ...       ...                          ...        ...
# 45371   30840                   Robin Hood   0.000000
# 45372  111109          Century of Birthing   0.000000
# 45373   67758                     Betrayal   0.000000
# 45374  227506             Satan Triumphant   0.000000
# 45375  461257                     Queerama   0.000000
#
# [45376 rows x 3 columns]

# %%
movieId_title_return.rename(columns={'id': 'movie_id'}, inplace=True)
movieId_title_return
# Out:
#       movie_id                        title     return
# 0          862                    Toy Story  12.451801
# 1         8844                      Jumanji   4.043035
# 2        15602             Grumpier Old Men   0.000000
# 3        31357            Waiting to Exhale   5.090760
# 4        11862  Father of the Bride Part II   0.000000
# ...        ...                          ...        ...
# 45371    30840                   Robin Hood   0.000000
# 45372   111109          Century of Birthing   0.000000
# 45373    67758                     Betrayal   0.000000
# 45374   227506             Satan Triumphant   0.000000
# 45375   461257                     Queerama   0.000000
#
# [45376 rows x 3 columns]

# %%
movieId_title_return[movieId_title_return['movie_id'] == "208988"]
# Out:
#       movie_id    title  return
# 19144   208988  The War     0.0

# %%
peliculas_tom_hanks = pd.merge(name_movieId_tom_hanks, movieId_title_return)
peliculas_tom_hanks
# Out:
#          name movie_id                 title     return
# 0   Tom Hanks      862             Toy Story  12.451801
# 1   Tom Hanks      568             Apollo 13   6.831499
# 2   Tom Hanks       13          Forrest Gump  12.326280
# 3   Tom Hanks     9800          Philadelphia   7.949171
# 4   Tom Hanks      858  Sleepless in Seattle  10.847614
# ..        ...      ...                   ...        ...
# 66  Tom Hanks   363676                 Sully   3.974501
# 67  Tom Hanks   207932               Inferno   2.933617
# 68  Tom Hanks   140465           Prohibition   0.000000
# 69  Tom Hanks   305642                Ithaca   0.000000
# 70  Tom Hanks   331214      Band of Brothers   0.000000
#
# [71 rows x 4 columns]

# %%
peliculas_tom_hanks = peliculas_tom_hanks[peliculas_tom_hanks['return'] != 0]
peliculas_tom_hanks
# Out:
#          name movie_id                              title     return
# 0   Tom Hanks      862                          Toy Story  12.451801
# 1   Tom Hanks      568                          Apollo 13   6.831499
# 2   Tom Hanks       13                       Forrest Gump  12.326280
# 3   Tom Hanks     9800                       Philadelphia   7.949171
# 4   Tom Hanks      858               Sleepless in Seattle  10.847614
# 7   Tom Hanks      857                Saving Private Ryan   6.883442
# 8   Tom Hanks    11974                         The 'Burbs   2.033444
# 9   Tom Hanks     2619                             Splash   8.727667
# 10  Tom Hanks    10466                      The Money Pit   5.499965
# 12  Tom Hanks     9489                    You've Got Mail   3.858792
# 13  Tom Hanks     2280                                Big   8.426043
# 15  Tom Hanks      863                        Toy Story 2   5.526299
# 16  Tom Hanks     9586        The Bonfire of the Vanities   0.333855
# 17  Tom Hanks      497                     The Green Mile   4.743333
# 18  Tom Hanks    11287              A League of Their Own   2.686470
# 20  Tom Hanks    12309                     Bachelor Party   6.405991
# 21  Tom Hanks    40820                          Punchline   1.402151
# 22  Tom Hanks     8358                          Cast Away   4.773690
# 26  Tom Hanks     4147                  Road to Perdition   2.262518
# 27  Tom Hanks      640                Catch Me If You Can   6.771429
# 28  Tom Hanks    20763                        Radio Flyer   0.132914
# 29  Tom Hanks    10023                            Dragnet   3.333676
# 31  Tom Hanks      594                       The Terminal   3.656954
# 33  Tom Hanks     5255                  The Polar Express   1.853792
# 35  Tom Hanks      591                  The Da Vinci Code   6.142564
# 36  Tom Hanks      920                               Cars   3.849860
# 37  Tom Hanks    13508       Who Killed the Electric Car?   1.678874
# 38  Tom Hanks       35                 The Simpsons Movie   7.027585
# 39  Tom Hanks     6538               Charlie Wilson's War   1.586672
# 41  Tom Hanks    13448                    Angels & Demons   2.377423
# 43  Tom Hanks    10193                        Toy Story 3   5.334849
# 45  Tom Hanks    59861                       Larry Crowne   1.205346
# 46  Tom Hanks    64685  Extremely Loud & Incredibly Close   1.381197
# 48  Tom Hanks    83542                        Cloud Atlas   1.279244
# 50  Tom Hanks   109424                   Captain Phillips   1.727273
# 52  Tom Hanks   140823                   Saving Mr. Banks   3.215559
# 60  Tom Hanks   339988                         The Circle   1.138769
# 61  Tom Hanks   296098                    Bridge of Spies   4.136959
# 64  Tom Hanks   270010            A Hologram for the King   0.140416
# 66  Tom Hanks   363676                              Sully   3.974501
# 67  Tom Hanks   207932                            Inferno   2.933617

# %%
peliculas_tom_hanks.reset_index(inplace=True)

# %%
peliculas_tom_hanks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     41 non-null     int64
#  1   name      41 non-null     object
#  2   movie_id  41 non-null     object
#  3   title     41 non-null     object
#  4   return    41 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.7+ KB

# %%
promedio_retorno = peliculas_tom_hanks["return"].mean()
promedio_retorno
# Out:
# 4.362182830614692

# %%
promedio_retorno = peliculas_tom_hanks["return"].sum()
promedio_retorno
# Out:
# 178.8494960552024

# %%
cast_df
# Out:
#        cast_id                character                 credit_id gender  \
# 0           14            Woody (voice)  52fe4284c3a36847f8024f95      2
# 1           15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99      2
# 2           16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d      2
# 3           17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1      2
# 4           18              Rex (voice)  52fe4284c3a36847f8024fa5      2
# ...        ...                      ...                       ...    ...
# 562469       2                           52fe4ea59251416c7515d7d5      2
# 562470       3                           52fe4ea59251416c7515d7d9      1
# 562471       4                           52fe4ea59251416c7515d7dd      2
# 562472       5                           52fe4ea59251416c7515d7e1      0
# 562473       6                           52fe4ea59251416c7515d7e5      1
#
#              id               name order                      profile_path  \
# 0            31          Tom Hanks     0  /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
# 1         12898          Tim Allen     1  /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
# 2          7167        Don Rickles     2  /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
# 3         12899         Jim Varney     3  /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
# 4         12900      Wallace Shawn     4  /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg
# ...         ...                ...   ...                               ...
# 562469   544742   Iwan Mosschuchin     0                              None
# 562470  1090923  Nathalie Lissenko     1                              None
# 562471  1136422       Pavel Pavlov     2                              None
# 562472  1261758  Aleksandr Chabrov     3                              None
# 562473    29199        Vera Orlova     4  /n1NXVGNzNxtqsMWxLT1h8GO8Kpi.jpg
#
#        movie_id
# 0           862
# 1           862
# 2           862
# 3           862
# 4           862
# ...         ...
# 562469   227506
# 562470   227506
# 562471   227506
# 562472   227506
# 562473   227506
#
# [562474 rows x 9 columns]

# %%
def get_actor(nombre_actor):
    name_movieId = cast_df[['name', 'movie_id']]
    nombreActor_movieId = name_movieId[name_movieId['name'] == nombre_actor]
    nombreActor_movieId = nombreActor_movieId.drop_duplicates(subset=['movie_id'])
    cantidad_peliculas = len(nombreActor_movieId['movie_id'])
    movieId_title_return = pd.DataFrame(movies_df[['id','title','return']])
    movieId_title_return.rename(columns={'id': 'movie_id'}, inplace=True)
    nombreActor_peliculas = pd.merge(nombreActor_movieId, movieId_title_return)
    nombreActor_peliculas = nombreActor_peliculas[nombreActor_peliculas['return'] != 0]
    nombreActor_peliculas.reset_index(inplace=True)
    cantidad_peliculas_con_retorno = len(nombreActor_peliculas['movie_id'])
    total_retorno = nombreActor_peliculas["return"].sum()
    promedio_retorno = nombreActor_peliculas["return"].mean()
    return (cantidad_peliculas, cantidad_peliculas_con_retorno, total_retorno, promedio_retorno)

# %%
get_actor("Tom Hanks")
# Out:
# (71, 41, 178.8494960552024, 4.362182830614692)

# %%
crew_df = pd.read_parquet('../data/credits/crew_ETL.parquet', engine='fastparquet')

# %%
crew_df.iloc[1]
# Out:
# credit_id               52fe4284c3a36847f8024f4f
# department                               Writing
# gender                                         2
# id                                         12891
# job                                   Screenplay
# name                                 Joss Whedon
# profile_path    /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
# movie_id                                     862
# Name: 1, dtype: object
