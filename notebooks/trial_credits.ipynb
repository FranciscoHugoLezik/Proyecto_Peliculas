# %% [markdown]
# Extraction

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Importacion en un dataframe del archivo cast.parquet ubicado en la carpeta credits que a su vez esta en la carpeta data.

# %%
cast_df = pd.read_parquet('../data/movies_data/credits/cast.parquet', engine='fastparquet')
cast_df.head()
# Out:
#                                                 cast
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...

# %% [markdown]
# Transform

# %%
print(cast_df.shape)
# Out:
# (45476, 1)

# %%
print(cast_df.columns)
# Out:
# Index(['cast'], dtype='object')

# %%
cast_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
# dtypes: object(1)
# memory usage: 355.4+ KB

# %%
print(cast_df['cast'])
# Out:
# 0        [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1        [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2        [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3        [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4        [{'cast_id': 1, 'character': 'George Banks', '...
#                                ...
# 45471    [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472    [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473    [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474    [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                   []
# Name: cast, Length: 45476, dtype: object

# %%
print(cast_df['cast'][0])
# Out:
# [{'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}, {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}, {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}, {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}, {'cast_id': 18, 'character': 'Rex (voice)', 'credit_id': '52fe4284c3a36847f8024fa5', 'gender': 2, 'id': 12900, 'name': 'Wallace Shawn', 'order': 4, 'profile_path': '/oGE6JqPP2xH4
# ...

# %%
first_cast = cast_df['cast'][0]

# %%
type(first_cast)
# Out:
# str

# %%
import json

# %%
first_cast = first_cast.replace("'",'"')

# %%
first_cast = json.loads(first_cast)
print(type(first_cast))
print(first_cast)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 first_cast = json.loads(first_cast)
#       2 print(type(first_cast))
#       3 print(first_cast)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...

# %%
context = first_cast[2405:2425]
print(context)
# Out:
# le_path": None}, {"c

# %%
first_cast = first_cast.replace("None", "null")

# %%
first_cast_list = json.loads(first_cast)
print(type(first_cast_list))
print(first_cast_list)
# Out:
# <class 'list'>
# ...

# %%
for item in first_cast_list:
    print(item)
# Out:
# {'cast_id': 14, 'character': 'Woody (voice)', 'credit_id': '52fe4284c3a36847f8024f95', 'gender': 2, 'id': 31, 'name': 'Tom Hanks', 'order': 0, 'profile_path': '/pQFoyx7rp09CJTAb932F2g8Nlho.jpg'}
# {'cast_id': 15, 'character': 'Buzz Lightyear (voice)', 'credit_id': '52fe4284c3a36847f8024f99', 'gender': 2, 'id': 12898, 'name': 'Tim Allen', 'order': 1, 'profile_path': '/uX2xVf6pMmPepxnvFWyBtjexzgY.jpg'}
# {'cast_id': 16, 'character': 'Mr. Potato Head (voice)', 'credit_id': '52fe4284c3a36847f8024f9d', 'gender': 2, 'id': 7167, 'name': 'Don Rickles', 'order': 2, 'profile_path': '/h5BcaDMPRVLHLDzbQavec4xfSdt.jpg'}
# {'cast_id': 17, 'character': 'Slinky Dog (voice)', 'credit_id': '52fe4284c3a36847f8024fa1', 'gender': 2, 'id': 12899, 'name': 'Jim Varney', 'order': 3, 'profile_path': '/eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg'}
# ...

# %%
for item in first_cast_list:
    for key, value in item.items():
        print(f'{key}: {value}')
    print()
# Out:
# cast_id: 14
# character: Woody (voice)
# credit_id: 52fe4284c3a36847f8024f95
# gender: 2
# id: 31
# name: Tom Hanks
# order: 0
# profile_path: /pQFoyx7rp09CJTAb932F2g8Nlho.jpg
#
# cast_id: 15
# character: Buzz Lightyear (voice)
# credit_id: 52fe4284c3a36847f8024f99
# gender: 2
# id: 12898
# name: Tim Allen
# order: 1
# profile_path: /uX2xVf6pMmPepxnvFWyBtjexzgY.jpg
#
# cast_id: 16
# character: Mr. Potato Head (voice)
# credit_id: 52fe4284c3a36847f8024f9d
# gender: 2
# id: 7167
# name: Don Rickles
# order: 2
# profile_path: /h5BcaDMPRVLHLDzbQavec4xfSdt.jpg
#
# cast_id: 17
# character: Slinky Dog (voice)
# credit_id: 52fe4284c3a36847f8024fa1
# gender: 2
# id: 12899
# name: Jim Varney
# order: 3
# profile_path: /eIo2jVVXYgjDtaHoF19Ll9vtW7h.jpg
#
# cast_id: 18
# character: Rex (voice)
# credit_id: 52fe4284c3a36847f8024fa5
# gender: 2
# id: 12900
# name: Wallace Shawn
# order: 4
# profile_path: /oGE6JqPP2xH4tNORKNqxbNPYi7u.jpg
#
# cast_id: 19
# character: Hamm (voice)
# ...

# %%
crew_df = pd.read_parquet('../data/movies_data/credits/crew.parquet', engine='fastparquet')
crew_df.head()
# Out:
#                                                 crew
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...

# %%
crew_df.shape
# Out:
# (45476, 1)

# %%
crew_df.columns
# Out:
# Index(['crew'], dtype='object')

# %%
crew_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   crew    45476 non-null  object
# dtypes: object(1)
# memory usage: 355.4+ KB

# %%
crew_df['crew']
# Out:
# 0        [{'credit_id': '52fe4284c3a36847f8024f49', 'de...
# 1        [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...
# 2        [{'credit_id': '52fe466a9251416c75077a89', 'de...
# 3        [{'credit_id': '52fe44779251416c91011acb', 'de...
# 4        [{'credit_id': '52fe44959251416c75039ed7', 'de...
#                                ...
# 45471    [{'credit_id': '5894a97d925141426c00818c', 'de...
# 45472    [{'credit_id': '52fe4af1c3a36847f81e9b15', 'de...
# 45473    [{'credit_id': '52fe4776c3a368484e0c8387', 'de...
# 45474    [{'credit_id': '533bccebc3a36844cf0011a7', 'de...
# 45475    [{'credit_id': '593e676c92514105b702e68e', 'de...
# Name: crew, Length: 45476, dtype: object

# %%
crew_df['crew'][0]
# Out:
# '[{\'credit_id\': \'52fe4284c3a36847f8024f49\', \'department\': \'Directing\', \'gender\': 2, \'id\': 7879, \'job\': \'Director\', \'name\': \'John Lasseter\', \'profile_path\': \'/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f4f\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12891, \'job\': \'Screenplay\', \'name\': \'Joss Whedon\', \'profile_path\': \'/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f55\', \'department\': \'Writing\', \'gender\': 2, \'id\': 7, \'job\': \'Screenplay\', \'name\': \'Andrew Stanton\', \'profile_path\': \'/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f5b\', \'department\': \'Writing\', \'gender\': 2, \'id\': 12892, \'job\': \'Screenplay\', \'name\': \'Joel Cohen\', \'profile_path\': \'/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg\'}, {\'credit_id\': \'52fe4284c3a36847f8024f61\', \'department\': \'Writing\', \'gender\': 0, \'id\': 12893, \'job\': \'Screenplay\', \'name\': \
# ...

# %%
first_crew = crew_df['crew'][0]
type(first_crew)
# Out:
# str

# %%
first_crew = first_crew.replace("'",'"')

# %%
first_crew
# Out:
# '[{"credit_id": "52fe4284c3a36847f8024f49", "department": "Directing", "gender": 2, "id": 7879, "job": "Director", "name": "John Lasseter", "profile_path": "/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg"}, {"credit_id": "52fe4284c3a36847f8024f4f", "department": "Writing", "gender": 2, "id": 12891, "job": "Screenplay", "name": "Joss Whedon", "profile_path": "/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg"}, {"credit_id": "52fe4284c3a36847f8024f55", "department": "Writing", "gender": 2, "id": 7, "job": "Screenplay", "name": "Andrew Stanton", "profile_path": "/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg"}, {"credit_id": "52fe4284c3a36847f8024f5b", "department": "Writing", "gender": 2, "id": 12892, "job": "Screenplay", "name": "Joel Cohen", "profile_path": "/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg"}, {"credit_id": "52fe4284c3a36847f8024f61", "department": "Writing", "gender": 0, "id": 12893, "job": "Screenplay", "name": "Alec Sokolow", "profile_path": "/v79vlRYi94BZUQnkkyznbGUZLjT.jpg"}, {"credit_id": "52fe4284c3a36847f8024f67", "dep
# ...

# %%
first_crew = json.loads(first_crew)
print(type(first_crew))
first_crew
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 first_crew = json.loads(first_crew)
#       2 print(type(first_crew))
#       3 first_crew
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...

# %%
context = first_crew[1100:1120]
print(context)
# Out:
# path": null}, {"cred

# %%
first_crew = first_crew.replace("None", "null")

# %%
first_crew_list = json.loads(first_crew)
type(first_crew_list)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 first_crew_list = json.loads(first_crew)
#       2 type(first_crew_list)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...

# %%
print(first_crew[14795])
print(first_crew[14796])
print(first_crew[14797])
print(first_crew[14798])
# Out:
# "
# C
# o
# n

# %%
context = first_crew[14770:14830]
print(context)
# Out:
# resser", "name": "Kelly O"Connell", "profile_path": null}, {

# %%
first_crew_list = list(first_crew)
first_crew_list
# Out:
# ['[',
#  '{',
#  '"',
#  'c',
#  'r',
#  'e',
#  'd',
#  'i',
#  't',
#  '_',
#  'i',
#  'd',
#  '"',
#  ':',
#  ' ',
#  '"',
#  '5',
#  '2',
#  'f',
#  'e',
#  '4',
#  '2',
#  '8',
#  '4',
#  'c',
#  '3',
#  'a',
#  '3',
#  '6',
#  '8',
#  '4',
#  '7',
#  'f',
#  '8',
#  '0',
#  '2',
#  '4',
#  'f',
#  '4',
#  '9',
#  '"',
#  ',',
#  ' ',
#  '"',
#  'd',
#  'e',
#  'p',
#  'a',
#  'r',
#  't',
#  'm',
#  'e',
#  'n',
#  't',
#  '"',
#  ':',
#  ' ',
#  '"',
#  'D',
#  'i',
#  'r',
#  'e',
#  'c',
#  't',
#  'i',
#  'n',
#  'g',
#  '"',
#  ',',
#  ' ',
#  '"',
#  'g',
#  'e',
#  'n',
#  'd',
#  'e',
#  'r',
#  '"',
#  ':',
#  ' ',
#  '2',
#  ',',
#  ' ',
#  '"',
#  'i',
#  'd',
#  '"',
#  ':',
#  ' ',
#  '7',
#  '8',
#  '7',
#  '9',
#  ',',
#  ' ',
#  '"',
#  'j',
#  'o',
#  'b',
#  '"',
#  ':',
#  ' ',
#  '"',
#  'D',
#  'i',
#  'r',
#  'e',
#  'c',
#  't',
#  'o',
#  'r',
#  '"',
#  ',',
#  ' ',
#  '"',
#  'n',
#  'a',
#  'm',
#  'e',
#  '"',
#  ':',
#  ' ',
#  '"',
#  'J',
#  'o',
# ...

# %%
print(first_crew_list[14795])
print(first_crew_list[14796])
print(first_crew_list[14797])
print(first_crew_list[14798])
# Out:
# "
# C
# o
# n

# %%
first_crew_list[14795] = "'"
first_crew_list[14795]
# Out:
# "'"

# %%
first_crew_str = ''.join(first_crew_list)
first_crew_str
# Out:
# '[{"credit_id": "52fe4284c3a36847f8024f49", "department": "Directing", "gender": 2, "id": 7879, "job": "Director", "name": "John Lasseter", "profile_path": "/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg"}, {"credit_id": "52fe4284c3a36847f8024f4f", "department": "Writing", "gender": 2, "id": 12891, "job": "Screenplay", "name": "Joss Whedon", "profile_path": "/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg"}, {"credit_id": "52fe4284c3a36847f8024f55", "department": "Writing", "gender": 2, "id": 7, "job": "Screenplay", "name": "Andrew Stanton", "profile_path": "/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg"}, {"credit_id": "52fe4284c3a36847f8024f5b", "department": "Writing", "gender": 2, "id": 12892, "job": "Screenplay", "name": "Joel Cohen", "profile_path": "/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg"}, {"credit_id": "52fe4284c3a36847f8024f61", "department": "Writing", "gender": 0, "id": 12893, "job": "Screenplay", "name": "Alec Sokolow", "profile_path": "/v79vlRYi94BZUQnkkyznbGUZLjT.jpg"}, {"credit_id": "52fe4284c3a36847f8024f67", "dep
# ...

# %%
first_crew_list = json.loads(first_crew_str)
type(first_crew_list)
# Out:
# list

# %%
print(first_crew_list)
# Out:
# [{'credit_id': '52fe4284c3a36847f8024f49', 'department': 'Directing', 'gender': 2, 'id': 7879, 'job': 'Director', 'name': 'John Lasseter', 'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'}, {'credit_id': '52fe4284c3a36847f8024f4f', 'department': 'Writing', 'gender': 2, 'id': 12891, 'job': 'Screenplay', 'name': 'Joss Whedon', 'profile_path': '/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg'}, {'credit_id': '52fe4284c3a36847f8024f55', 'department': 'Writing', 'gender': 2, 'id': 7, 'job': 'Screenplay', 'name': 'Andrew Stanton', 'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'}, {'credit_id': '52fe4284c3a36847f8024f5b', 'department': 'Writing', 'gender': 2, 'id': 12892, 'job': 'Screenplay', 'name': 'Joel Cohen', 'profile_path': '/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg'}, {'credit_id': '52fe4284c3a36847f8024f61', 'department': 'Writing', 'gender': 0, 'id': 12893, 'job': 'Screenplay', 'name': 'Alec Sokolow', 'profile_path': '/v79vlRYi94BZUQnkkyznbGUZLjT.jpg'}, {'credit_id': '52fe4284c3a36847f8024f67', 'depa
# ...

# %%
for item in first_crew_list:
    for key, value in item.items():
        print(f'{key}: {value}')
    print()
# Out:
# credit_id: 52fe4284c3a36847f8024f49
# department: Directing
# gender: 2
# id: 7879
# job: Director
# name: John Lasseter
# profile_path: /7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg
#
# credit_id: 52fe4284c3a36847f8024f4f
# department: Writing
# gender: 2
# id: 12891
# job: Screenplay
# name: Joss Whedon
# profile_path: /dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg
#
# credit_id: 52fe4284c3a36847f8024f55
# department: Writing
# gender: 2
# id: 7
# job: Screenplay
# name: Andrew Stanton
# profile_path: /pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg
#
# credit_id: 52fe4284c3a36847f8024f5b
# department: Writing
# gender: 2
# id: 12892
# job: Screenplay
# name: Joel Cohen
# profile_path: /dAubAiZcvKFbboWlj7oXOkZnTSu.jpg
#
# credit_id: 52fe4284c3a36847f8024f61
# department: Writing
# gender: 0
# id: 12893
# job: Screenplay
# name: Alec Sokolow
# profile_path: /v79vlRYi94BZUQnkkyznbGUZLjT.jpg
#
# credit_id: 52fe4284c3a36847f8024f67
# department: Production
# gender: 1
# id: 12894
# job: Producer
# name: Bonnie Arnold
# ...

# %%
id_df = pd.read_parquet('../data/movies_data/credits/id.parquet', engine='fastparquet')
id_df.head()
# Out:
#       id
# 0    862
# 1   8844
# 2  15602
# 3  31357
# 4  11862

# %%
print(id_df.shape)
print(id_df.columns)
print(id_df.info())
# Out:
# (45476, 1)
# Index(['id'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      45476 non-null  int64
# dtypes: int64(1)
# memory usage: 355.4 KB
# None

# %%
print(id_df['id'][0])
# Out:
# 862

# %%
type(id_df['id'][0])
# Out:
# numpy.int64

# %%
id_int = int(id_df['id'][0])
id_int
# Out:
# 862

# %%
first_id_df = pd.DataFrame({'id': [id_df['id'][0]]})
print(type(first_id_df))
first_id_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     id
# 0  862

# %%
first_id_df
# Out:
#     id
# 0  862

# %%
first_cast_df = pd.DataFrame(first_cast_list)
first_cast_df
# Out:
#     cast_id                character                 credit_id  gender  \
# 0        14            Woody (voice)  52fe4284c3a36847f8024f95       2
# 1        15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2
# 2        16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2
# 3        17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2
# 4        18              Rex (voice)  52fe4284c3a36847f8024fa5       2
# 5        19             Hamm (voice)  52fe4284c3a36847f8024fa9       2
# 6        20          Bo Peep (voice)  52fe4284c3a36847f8024fad       1
# 7        26             Andy (voice)  52fe4284c3a36847f8024fc1       0
# 8        22              Sid (voice)  52fe4284c3a36847f8024fb1       2
# 9        23       Mrs. Davis (voice)  52fe4284c3a36847f8024fb5       1
# 10       24         Sergeant (voice)  52fe4284c3a36847f8024fb9       2
# 11       25           Hannah (voice)  52fe4284c3a36847f8024fbd       1
# ...

# %%
type(first_cast_df)
# Out:
# pandas.core.frame.DataFrame

# %%
first_id_df_repeat = pd.concat([first_id_df] * len(first_cast_df), ignore_index=True)

# %%
first_id_df_repeat
# Out:
#      id
# 0   862
# 1   862
# 2   862
# 3   862
# 4   862
# 5   862
# 6   862
# 7   862
# 8   862
# 9   862
# 10  862
# 11  862
# 12  862

# %%
first_cast_id_df = pd.concat([first_id_df_repeat.reset_index(drop=True), first_cast_df.reset_index(drop=True)], axis=1)

# %%
first_cast_id_df
# Out:
#      id  cast_id                character                 credit_id  gender  \
# 0   862       14            Woody (voice)  52fe4284c3a36847f8024f95       2
# 1   862       15   Buzz Lightyear (voice)  52fe4284c3a36847f8024f99       2
# 2   862       16  Mr. Potato Head (voice)  52fe4284c3a36847f8024f9d       2
# 3   862       17       Slinky Dog (voice)  52fe4284c3a36847f8024fa1       2
# 4   862       18              Rex (voice)  52fe4284c3a36847f8024fa5       2
# 5   862       19             Hamm (voice)  52fe4284c3a36847f8024fa9       2
# 6   862       20          Bo Peep (voice)  52fe4284c3a36847f8024fad       1
# 7   862       26             Andy (voice)  52fe4284c3a36847f8024fc1       0
# 8   862       22              Sid (voice)  52fe4284c3a36847f8024fb1       2
# 9   862       23       Mrs. Davis (voice)  52fe4284c3a36847f8024fb5       1
# 10  862       24         Sergeant (voice)  52fe4284c3a36847f8024fb9       2
# ...
